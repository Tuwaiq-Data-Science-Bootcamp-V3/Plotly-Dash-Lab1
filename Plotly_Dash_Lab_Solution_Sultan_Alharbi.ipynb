# %% [markdown]
# # Q0: import dash standard libraries

# %%
from dash import Dash, dcc, html, Input, Output
import plotly.graph_objects as go
from jupyter_dash import JupyterDash
from dash import Dash, html
import pandas as pd
import plotly.express as px
import numpy as np

# %% [markdown]
# # Q1: Make dash that prints "Data Science"

# %%
app=Dash(__name__)

app.layout=html.Div([html.H1("Data Science")])

if __name__ =="__main__":
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [31/May/2023 19:31:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2023 19:31:08] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2023 19:31:08] "GET /_dash-dependencies HTTP/1.1" 200 -

# %% [markdown]
# # Q2: Make dash that takes name input and outpt "Welcome to Data Science dashboard {name}"

# %%
app = JupyterDash(__name__)

app.layout = html.Div([
    html.H6("Enter Your Name : "),
    html.Div([
        "Input: ",
        dcc.Input(id='my-input', value='initial value', type='text')
    ]),
    html.Br(),
    html.Div(id='my-output'),

])


@app.callback(
    Output(component_id='my-output', component_property='children'),
    Input(component_id='my-input', component_property='value'),
)
def update_output_div(input_value):
    return f'Welcome to Data Science dashboard {input_value}'


if __name__ == '__main__':
    app.run_server(mode='inline')
# Out:
# Dash is running on http://127.0.0.1:8050/
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Q3: Make Plotly-Dash that takes two inputs (numbers) and output 3 numbers x, y , z= x+y
# - hint: use html.Div, dcc.Input(type='number')

# %%
# from dash import Dash, dcc, html, Input, Output
# from jupyter_dash import JupyterDash

app = JupyterDash(__name__)

app.layout = html.Div([
    html.H6("Please Enter 2 numbers : "),
    html.Div([
        "Input: ",
        dcc.Input(id='my-input', value='initial value', type='number')
    ]),
    html.Div([
        "Input: ",
        dcc.Input(id='my-input2', value='initial value 2', type='number')
    ]),
    html.Br(),
    html.Div(id='my-output'),

])


@app.callback(
    Output(component_id='my-output', component_property='children'),
    Input(component_id='my-input', component_property='value'),
    Input(component_id='my-input2', component_property='value')
)
def update_output_div(input_value, input_value2):
    return f'=: {input_value+input_value2}'


if __name__ == '__main__':
    app.run_server(mode='inline')
# Out:
# Dash is running on http://127.0.0.1:8050/
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
#
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\flask\app.py:1950, in Flask.full_dispatch_request(self=<Flask '__main__'>)
#    1948     rv = self.preprocess_request()
#    1949     if rv is None:
# -> 1950         rv = self.dispatch_request()
#         rv = None
#         self = <Flask '__main__'>
#    1951 except Exception as e:
#    1952     rv = self.handle_user_exception(e)
#
# File ~\anaconda3\lib\site-packages\flask\app.py:1936, in Flask.dispatch_request(self=<Flask '__main__'>)
#    1934     return self.make_default_options_response()
#    1935 # otherwise dispatch to the handler for that endpoint
# -> 1936 return self.view_functions[rule.endpoint](**req.view_args)
#         req = <Request 'http://127.0.0.1:8050/_dash-update-component' [POST]>
#         rule = <Rule '/_dash-update-component' (POST, OPTIONS) -> /_dash-update-component>
#         self.view_functions[rule.endpoint] = <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>
#         self.view_functions = {'static': <bound method _PackageBoundObject.send_static_file of <Flask '__main__'>>, '_dash_assets.static': <bound method _PackageBoundObject.send_static_file of <flask.blueprints.Blueprint object at 0x00000200F82DC850>>, '/_dash-component-suites/<string:package_name>/<path:fingerprinted_path>': <bound method Dash.serve_component_suites of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-layout': <bound method Dash.serve_layout of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-dependencies': <bound method Dash.dependencies of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-update-component': <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_reload-hash': <bound method Dash.serve_reload_hash of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_favicon.ico': <function Dash._serve_default_favicon at 0x00000200F7FC8CA0>, '/': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/<path:path>': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, 'alive': <function JupyterDash.__init__.<locals>.alive at 0x00000200F6828E50>}
#         rule.endpoint = '/_dash-update-component'
#         req.view_args = {}
#         self = <Flask '__main__'>
#
# File ~\anaconda3\lib\site-packages\dash\dash.py:1214, in Dash.dispatch(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1211             update_args_group(pattern_match_g, changed_props)
#    1212     update_args_group(s, changed_props)
# -> 1214 args_grouping = map_grouping(
#         inputs_state_indices = [0, 1]
#         inputs_state = [{'id': 'my-input', 'property': 'value', 'value': 's', 'str_id': 'my-input', 'triggered': True}]
#    1215     lambda ind: inputs_state[ind], inputs_state_indices
#    1216 )
#    1218 g.args_grouping = args_grouping  # pylint: disable=assigning-non-slot
#    1219 g.using_args_grouping = (  # pylint: disable=assigning-non-slot
#    1220     not isinstance(inputs_state_indices, int)
#    1221     and (
#    (...)
#    1224     )
#    1225 )
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:124, in map_grouping(
#     fn=<function Dash.dispatch.<locals>.<lambda>>,
#     grouping=[0, 1]
# )
#     114 """
#     115 Map a function over all of the scalar values of a grouping, maintaining the
#     116 grouping structure
#    (...)
#     121     values updated by the input function.
#     122 """
#     123 if isinstance(grouping, (tuple, list)):
# --> 124     return [map_grouping(fn, g) for g in grouping]
#         grouping = [0, 1]
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F8FB3B80>
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:124, in <listcomp>(.0=<list_iterator object>)
#     114 """
#     115 Map a function over all of the scalar values of a grouping, maintaining the
#     116 grouping structure
#    (...)
#     121     values updated by the input function.
#     122 """
#     123 if isinstance(grouping, (tuple, list)):
# --> 124     return [map_grouping(fn, g) for g in grouping]
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F8FB3B80>
#         g = 1
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:129, in map_grouping(
#     fn=<function Dash.dispatch.<locals>.<lambda>>,
#     grouping=1
# )
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
# --> 129 return fn(grouping)
#         grouping = 1
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F8FB3B80>
#
# File ~\anaconda3\lib\site-packages\dash\dash.py:1215, in Dash.dispatch.<locals>.<lambda>(ind=1)
#    1211             update_args_group(pattern_match_g, changed_props)
#    1212     update_args_group(s, changed_props)
#    1214 args_grouping = map_grouping(
# -> 1215     lambda ind: inputs_state[ind], inputs_state_indices
#         inputs_state = [{'id': 'my-input', 'property': 'value', 'value': 's', 'str_id': 'my-input', 'triggered': True}]
#         ind = 1
#    1216 )
#    1218 g.args_grouping = args_grouping  # pylint: disable=assigning-non-slot
#    1219 g.using_args_grouping = (  # pylint: disable=assigning-non-slot
#    1220     not isinstance(inputs_state_indices, int)
#    1221     and (
#    (...)
#    1224     )
#    1225 )
#
# IndexError: list index out of range
#
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\flask\app.py:1950, in Flask.full_dispatch_request(self=<Flask '__main__'>)
#    1948     rv = self.preprocess_request()
#    1949     if rv is None:
# -> 1950         rv = self.dispatch_request()
#         rv = None
#         self = <Flask '__main__'>
#    1951 except Exception as e:
#    1952     rv = self.handle_user_exception(e)
#
# File ~\anaconda3\lib\site-packages\flask\app.py:1936, in Flask.dispatch_request(self=<Flask '__main__'>)
#    1934     return self.make_default_options_response()
#    1935 # otherwise dispatch to the handler for that endpoint
# -> 1936 return self.view_functions[rule.endpoint](**req.view_args)
#         req = <Request 'http://127.0.0.1:8050/_dash-update-component' [POST]>
#         rule = <Rule '/_dash-update-component' (POST, OPTIONS) -> /_dash-update-component>
#         self.view_functions[rule.endpoint] = <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>
#         self.view_functions = {'static': <bound method _PackageBoundObject.send_static_file of <Flask '__main__'>>, '_dash_assets.static': <bound method _PackageBoundObject.send_static_file of <flask.blueprints.Blueprint object at 0x00000200F82DC850>>, '/_dash-component-suites/<string:package_name>/<path:fingerprinted_path>': <bound method Dash.serve_component_suites of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-layout': <bound method Dash.serve_layout of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-dependencies': <bound method Dash.dependencies of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-update-component': <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_reload-hash': <bound method Dash.serve_reload_hash of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_favicon.ico': <function Dash._serve_default_favicon at 0x00000200F7FC8CA0>, '/': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/<path:path>': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, 'alive': <function JupyterDash.__init__.<locals>.alive at 0x00000200F6828E50>}
#         rule.endpoint = '/_dash-update-component'
#         req.view_args = {}
#         self = <Flask '__main__'>
#
# File ~\anaconda3\lib\site-packages\dash\dash.py:1214, in Dash.dispatch(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1211             update_args_group(pattern_match_g, changed_props)
#    1212     update_args_group(s, changed_props)
# -> 1214 args_grouping = map_grouping(
#         inputs_state_indices = [0, 1]
#         inputs_state = [{'id': 'my-input', 'property': 'value', 'value': 'su', 'str_id': 'my-input', 'triggered': True}]
#    1215     lambda ind: inputs_state[ind], inputs_state_indices
#    1216 )
#    1218 g.args_grouping = args_grouping  # pylint: disable=assigning-non-slot
#    1219 g.using_args_grouping = (  # pylint: disable=assigning-non-slot
#    1220     not isinstance(inputs_state_indices, int)
#    1221     and (
#    (...)
#    1224     )
#    1225 )
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:124, in map_grouping(
#     fn=<function Dash.dispatch.<locals>.<lambda>>,
#     grouping=[0, 1]
# )
#     114 """
#     115 Map a function over all of the scalar values of a grouping, maintaining the
#     116 grouping structure
#    (...)
#     121     values updated by the input function.
#     122 """
#     123 if isinstance(grouping, (tuple, list)):
# --> 124     return [map_grouping(fn, g) for g in grouping]
#         grouping = [0, 1]
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F91EEA60>
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:124, in <listcomp>(.0=<list_iterator object>)
#     114 """
#     115 Map a function over all of the scalar values of a grouping, maintaining the
#     116 grouping structure
#    (...)
#     121     values updated by the input function.
#     122 """
#     123 if isinstance(grouping, (tuple, list)):
# --> 124     return [map_grouping(fn, g) for g in grouping]
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F91EEA60>
#         g = 1
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:129, in map_grouping(
#     fn=<function Dash.dispatch.<locals>.<lambda>>,
#     grouping=1
# )
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
# --> 129 return fn(grouping)
#         grouping = 1
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F91EEA60>
#
# File ~\anaconda3\lib\site-packages\dash\dash.py:1215, in Dash.dispatch.<locals>.<lambda>(ind=1)
#    1211             update_args_group(pattern_match_g, changed_props)
#    1212     update_args_group(s, changed_props)
#    1214 args_grouping = map_grouping(
# -> 1215     lambda ind: inputs_state[ind], inputs_state_indices
#         inputs_state = [{'id': 'my-input', 'property': 'value', 'value': 'su', 'str_id': 'my-input', 'triggered': True}]
#         ind = 1
#    1216 )
#    1218 g.args_grouping = args_grouping  # pylint: disable=assigning-non-slot
#    1219 g.using_args_grouping = (  # pylint: disable=assigning-non-slot
#    1220     not isinstance(inputs_state_indices, int)
#    1221     and (
#    (...)
#    1224     )
#    1225 )
#
# IndexError: list index out of range
#
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\flask\app.py:1950, in Flask.full_dispatch_request(self=<Flask '__main__'>)
#    1948     rv = self.preprocess_request()
#    1949     if rv is None:
# -> 1950         rv = self.dispatch_request()
#         rv = None
#         self = <Flask '__main__'>
#    1951 except Exception as e:
#    1952     rv = self.handle_user_exception(e)
#
# File ~\anaconda3\lib\site-packages\flask\app.py:1936, in Flask.dispatch_request(self=<Flask '__main__'>)
#    1934     return self.make_default_options_response()
#    1935 # otherwise dispatch to the handler for that endpoint
# -> 1936 return self.view_functions[rule.endpoint](**req.view_args)
#         req = <Request 'http://127.0.0.1:8050/_dash-update-component' [POST]>
#         rule = <Rule '/_dash-update-component' (POST, OPTIONS) -> /_dash-update-component>
#         self.view_functions[rule.endpoint] = <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>
#         self.view_functions = {'static': <bound method _PackageBoundObject.send_static_file of <Flask '__main__'>>, '_dash_assets.static': <bound method _PackageBoundObject.send_static_file of <flask.blueprints.Blueprint object at 0x00000200F82DC850>>, '/_dash-component-suites/<string:package_name>/<path:fingerprinted_path>': <bound method Dash.serve_component_suites of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-layout': <bound method Dash.serve_layout of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-dependencies': <bound method Dash.dependencies of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-update-component': <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_reload-hash': <bound method Dash.serve_reload_hash of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_favicon.ico': <function Dash._serve_default_favicon at 0x00000200F7FC8CA0>, '/': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/<path:path>': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, 'alive': <function JupyterDash.__init__.<locals>.alive at 0x00000200F6828E50>}
#         rule.endpoint = '/_dash-update-component'
#         req.view_args = {}
#         self = <Flask '__main__'>
#
# File ~\anaconda3\lib\site-packages\dash\dash.py:1214, in Dash.dispatch(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1211             update_args_group(pattern_match_g, changed_props)
#    1212     update_args_group(s, changed_props)
# -> 1214 args_grouping = map_grouping(
#         inputs_state_indices = [0, 1]
#         inputs_state = [{'id': 'my-input', 'property': 'value', 'value': 'sul', 'str_id': 'my-input', 'triggered': True}]
#    1215     lambda ind: inputs_state[ind], inputs_state_indices
#    1216 )
#    1218 g.args_grouping = args_grouping  # pylint: disable=assigning-non-slot
#    1219 g.using_args_grouping = (  # pylint: disable=assigning-non-slot
#    1220     not isinstance(inputs_state_indices, int)
#    1221     and (
#    (...)
#    1224     )
#    1225 )
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:124, in map_grouping(
#     fn=<function Dash.dispatch.<locals>.<lambda>>,
#     grouping=[0, 1]
# )
#     114 """
#     115 Map a function over all of the scalar values of a grouping, maintaining the
#     116 grouping structure
#    (...)
#     121     values updated by the input function.
#     122 """
#     123 if isinstance(grouping, (tuple, list)):
# --> 124     return [map_grouping(fn, g) for g in grouping]
#         grouping = [0, 1]
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F91ED9D0>
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:124, in <listcomp>(.0=<list_iterator object>)
#     114 """
#     115 Map a function over all of the scalar values of a grouping, maintaining the
#     116 grouping structure
#    (...)
#     121     values updated by the input function.
#     122 """
#     123 if isinstance(grouping, (tuple, list)):
# --> 124     return [map_grouping(fn, g) for g in grouping]
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F91ED9D0>
#         g = 1
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:129, in map_grouping(
#     fn=<function Dash.dispatch.<locals>.<lambda>>,
#     grouping=1
# )
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
# --> 129 return fn(grouping)
#         grouping = 1
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F91ED9D0>
#
# File ~\anaconda3\lib\site-packages\dash\dash.py:1215, in Dash.dispatch.<locals>.<lambda>(ind=1)
#    1211             update_args_group(pattern_match_g, changed_props)
#    1212     update_args_group(s, changed_props)
#    1214 args_grouping = map_grouping(
# -> 1215     lambda ind: inputs_state[ind], inputs_state_indices
#         inputs_state = [{'id': 'my-input', 'property': 'value', 'value': 'sul', 'str_id': 'my-input', 'triggered': True}]
#         ind = 1
#    1216 )
#    1218 g.args_grouping = args_grouping  # pylint: disable=assigning-non-slot
#    1219 g.using_args_grouping = (  # pylint: disable=assigning-non-slot
#    1220     not isinstance(inputs_state_indices, int)
#    1221     and (
#    (...)
#    1224     )
#    1225 )
#
# IndexError: list index out of range
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\flask\app.py:1950, in Flask.full_dispatch_request(self=<Flask '__main__'>)
#    1948     rv = self.preprocess_request()
#    1949     if rv is None:
# -> 1950         rv = self.dispatch_request()
#         rv = None
#         self = <Flask '__main__'>
#    1951 except Exception as e:
#    1952     rv = self.handle_user_exception(e)
#
# File ~\anaconda3\lib\site-packages\flask\app.py:1936, in Flask.dispatch_request(self=<Flask '__main__'>)
#    1934     return self.make_default_options_response()
#    1935 # otherwise dispatch to the handler for that endpoint
# -> 1936 return self.view_functions[rule.endpoint](**req.view_args)
#         req = <Request 'http://127.0.0.1:8050/_dash-update-component' [POST]>
#         rule = <Rule '/_dash-update-component' (POST, OPTIONS) -> /_dash-update-component>
#         self.view_functions[rule.endpoint] = <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>
#         self.view_functions = {'static': <bound method _PackageBoundObject.send_static_file of <Flask '__main__'>>, '_dash_assets.static': <bound method _PackageBoundObject.send_static_file of <flask.blueprints.Blueprint object at 0x00000200F82DC850>>, '/_dash-component-suites/<string:package_name>/<path:fingerprinted_path>': <bound method Dash.serve_component_suites of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-layout': <bound method Dash.serve_layout of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-dependencies': <bound method Dash.dependencies of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-update-component': <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_reload-hash': <bound method Dash.serve_reload_hash of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_favicon.ico': <function Dash._serve_default_favicon at 0x00000200F7FC8CA0>, '/': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/<path:path>': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, 'alive': <function JupyterDash.__init__.<locals>.alive at 0x00000200F6828E50>}
#         rule.endpoint = '/_dash-update-component'
#         req.view_args = {}
#         self = <Flask '__main__'>
#
# File ~\anaconda3\lib\site-packages\dash\dash.py:1214, in Dash.dispatch(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1211             update_args_group(pattern_match_g, changed_props)
#    1212     update_args_group(s, changed_props)
# -> 1214 args_grouping = map_grouping(
#         inputs_state_indices = [0, 1]
#         inputs_state = [{'id': 'my-input', 'property': 'value', 'value': 'sult', 'str_id': 'my-input', 'triggered': True}]
#    1215     lambda ind: inputs_state[ind], inputs_state_indices
#    1216 )
#    1218 g.args_grouping = args_grouping  # pylint: disable=assigning-non-slot
#    1219 g.using_args_grouping = (  # pylint: disable=assigning-non-slot
#    1220     not isinstance(inputs_state_indices, int)
#    1221     and (
#    (...)
#    1224     )
#    1225 )
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:124, in map_grouping(
#     fn=<function Dash.dispatch.<locals>.<lambda>>,
#     grouping=[0, 1]
# )
#     114 """
#     115 Map a function over all of the scalar values of a grouping, maintaining the
#     116 grouping structure
#    (...)
#     121     values updated by the input function.
#     122 """
#     123 if isinstance(grouping, (tuple, list)):
# --> 124     return [map_grouping(fn, g) for g in grouping]
#         grouping = [0, 1]
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F91FFCA0>
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:124, in <listcomp>(.0=<list_iterator object>)
#     114 """
#     115 Map a function over all of the scalar values of a grouping, maintaining the
#     116 grouping structure
#    (...)
#     121     values updated by the input function.
#     122 """
#     123 if isinstance(grouping, (tuple, list)):
# --> 124     return [map_grouping(fn, g) for g in grouping]
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F91FFCA0>
#         g = 1
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:129, in map_grouping(
#     fn=<function Dash.dispatch.<locals>.<lambda>>,
#     grouping=1
# )
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
# --> 129 return fn(grouping)
#         grouping = 1
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F91FFCA0>
#
# File ~\anaconda3\lib\site-packages\dash\dash.py:1215, in Dash.dispatch.<locals>.<lambda>(ind=1)
#    1211             update_args_group(pattern_match_g, changed_props)
#    1212     update_args_group(s, changed_props)
#    1214 args_grouping = map_grouping(
# -> 1215     lambda ind: inputs_state[ind], inputs_state_indices
#         inputs_state = [{'id': 'my-input', 'property': 'value', 'value': 'sult', 'str_id': 'my-input', 'triggered': True}]
#         ind = 1
#    1216 )
#    1218 g.args_grouping = args_grouping  # pylint: disable=assigning-non-slot
#    1219 g.using_args_grouping = (  # pylint: disable=assigning-non-slot
#    1220     not isinstance(inputs_state_indices, int)
#    1221     and (
#    (...)
#    1224     )
#    1225 )
#
# IndexError: list index out of range
#
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\flask\app.py:1950, in Flask.full_dispatch_request(self=<Flask '__main__'>)
#    1948     rv = self.preprocess_request()
#    1949     if rv is None:
# -> 1950         rv = self.dispatch_request()
#         rv = None
#         self = <Flask '__main__'>
#    1951 except Exception as e:
#    1952     rv = self.handle_user_exception(e)
#
# File ~\anaconda3\lib\site-packages\flask\app.py:1936, in Flask.dispatch_request(self=<Flask '__main__'>)
#    1934     return self.make_default_options_response()
#    1935 # otherwise dispatch to the handler for that endpoint
# -> 1936 return self.view_functions[rule.endpoint](**req.view_args)
#         req = <Request 'http://127.0.0.1:8050/_dash-update-component' [POST]>
#         rule = <Rule '/_dash-update-component' (POST, OPTIONS) -> /_dash-update-component>
#         self.view_functions[rule.endpoint] = <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>
#         self.view_functions = {'static': <bound method _PackageBoundObject.send_static_file of <Flask '__main__'>>, '_dash_assets.static': <bound method _PackageBoundObject.send_static_file of <flask.blueprints.Blueprint object at 0x00000200F82DC850>>, '/_dash-component-suites/<string:package_name>/<path:fingerprinted_path>': <bound method Dash.serve_component_suites of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-layout': <bound method Dash.serve_layout of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-dependencies': <bound method Dash.dependencies of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-update-component': <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_reload-hash': <bound method Dash.serve_reload_hash of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_favicon.ico': <function Dash._serve_default_favicon at 0x00000200F7FC8CA0>, '/': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/<path:path>': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, 'alive': <function JupyterDash.__init__.<locals>.alive at 0x00000200F6828E50>}
#         rule.endpoint = '/_dash-update-component'
#         req.view_args = {}
#         self = <Flask '__main__'>
#
# File ~\anaconda3\lib\site-packages\dash\dash.py:1214, in Dash.dispatch(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1211             update_args_group(pattern_match_g, changed_props)
#    1212     update_args_group(s, changed_props)
# -> 1214 args_grouping = map_grouping(
#         inputs_state_indices = [0, 1]
#         inputs_state = [{'id': 'my-input', 'property': 'value', 'value': 'sulta', 'str_id': 'my-input', 'triggered': True}]
#    1215     lambda ind: inputs_state[ind], inputs_state_indices
#    1216 )
#    1218 g.args_grouping = args_grouping  # pylint: disable=assigning-non-slot
#    1219 g.using_args_grouping = (  # pylint: disable=assigning-non-slot
#    1220     not isinstance(inputs_state_indices, int)
#    1221     and (
#    (...)
#    1224     )
#    1225 )
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:124, in map_grouping(
#     fn=<function Dash.dispatch.<locals>.<lambda>>,
#     grouping=[0, 1]
# )
#     114 """
#     115 Map a function over all of the scalar values of a grouping, maintaining the
#     116 grouping structure
#    (...)
#     121     values updated by the input function.
#     122 """
#     123 if isinstance(grouping, (tuple, list)):
# --> 124     return [map_grouping(fn, g) for g in grouping]
#         grouping = [0, 1]
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F9283E50>
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:124, in <listcomp>(.0=<list_iterator object>)
#     114 """
#     115 Map a function over all of the scalar values of a grouping, maintaining the
#     116 grouping structure
#    (...)
#     121     values updated by the input function.
#     122 """
#     123 if isinstance(grouping, (tuple, list)):
# --> 124     return [map_grouping(fn, g) for g in grouping]
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F9283E50>
#         g = 1
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:129, in map_grouping(
#     fn=<function Dash.dispatch.<locals>.<lambda>>,
#     grouping=1
# )
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
# --> 129 return fn(grouping)
#         grouping = 1
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F9283E50>
#
# File ~\anaconda3\lib\site-packages\dash\dash.py:1215, in Dash.dispatch.<locals>.<lambda>(ind=1)
#    1211             update_args_group(pattern_match_g, changed_props)
#    1212     update_args_group(s, changed_props)
#    1214 args_grouping = map_grouping(
# -> 1215     lambda ind: inputs_state[ind], inputs_state_indices
#         inputs_state = [{'id': 'my-input', 'property': 'value', 'value': 'sulta', 'str_id': 'my-input', 'triggered': True}]
#         ind = 1
#    1216 )
#    1218 g.args_grouping = args_grouping  # pylint: disable=assigning-non-slot
#    1219 g.using_args_grouping = (  # pylint: disable=assigning-non-slot
#    1220     not isinstance(inputs_state_indices, int)
#    1221     and (
#    (...)
#    1224     )
#    1225 )
#
# IndexError: list index out of range
#
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\flask\app.py:1950, in Flask.full_dispatch_request(self=<Flask '__main__'>)
#    1948     rv = self.preprocess_request()
#    1949     if rv is None:
# -> 1950         rv = self.dispatch_request()
#         rv = None
#         self = <Flask '__main__'>
#    1951 except Exception as e:
#    1952     rv = self.handle_user_exception(e)
#
# File ~\anaconda3\lib\site-packages\flask\app.py:1936, in Flask.dispatch_request(self=<Flask '__main__'>)
#    1934     return self.make_default_options_response()
#    1935 # otherwise dispatch to the handler for that endpoint
# -> 1936 return self.view_functions[rule.endpoint](**req.view_args)
#         req = <Request 'http://127.0.0.1:8050/_dash-update-component' [POST]>
#         rule = <Rule '/_dash-update-component' (POST, OPTIONS) -> /_dash-update-component>
#         self.view_functions[rule.endpoint] = <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>
#         self.view_functions = {'static': <bound method _PackageBoundObject.send_static_file of <Flask '__main__'>>, '_dash_assets.static': <bound method _PackageBoundObject.send_static_file of <flask.blueprints.Blueprint object at 0x00000200F82DC850>>, '/_dash-component-suites/<string:package_name>/<path:fingerprinted_path>': <bound method Dash.serve_component_suites of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-layout': <bound method Dash.serve_layout of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-dependencies': <bound method Dash.dependencies of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-update-component': <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_reload-hash': <bound method Dash.serve_reload_hash of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_favicon.ico': <function Dash._serve_default_favicon at 0x00000200F7FC8CA0>, '/': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/<path:path>': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, 'alive': <function JupyterDash.__init__.<locals>.alive at 0x00000200F6828E50>}
#         rule.endpoint = '/_dash-update-component'
#         req.view_args = {}
#         self = <Flask '__main__'>
#
# File ~\anaconda3\lib\site-packages\dash\dash.py:1214, in Dash.dispatch(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1211             update_args_group(pattern_match_g, changed_props)
#    1212     update_args_group(s, changed_props)
# -> 1214 args_grouping = map_grouping(
#         inputs_state_indices = [0, 1]
#         inputs_state = [{'id': 'my-input', 'property': 'value', 'value': 'sultan', 'str_id': 'my-input', 'triggered': True}]
#    1215     lambda ind: inputs_state[ind], inputs_state_indices
#    1216 )
#    1218 g.args_grouping = args_grouping  # pylint: disable=assigning-non-slot
#    1219 g.using_args_grouping = (  # pylint: disable=assigning-non-slot
#    1220     not isinstance(inputs_state_indices, int)
#    1221     and (
#    (...)
#    1224     )
#    1225 )
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:124, in map_grouping(
#     fn=<function Dash.dispatch.<locals>.<lambda>>,
#     grouping=[0, 1]
# )
#     114 """
#     115 Map a function over all of the scalar values of a grouping, maintaining the
#     116 grouping structure
#    (...)
#     121     values updated by the input function.
#     122 """
#     123 if isinstance(grouping, (tuple, list)):
# --> 124     return [map_grouping(fn, g) for g in grouping]
#         grouping = [0, 1]
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F921A790>
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:124, in <listcomp>(.0=<list_iterator object>)
#     114 """
#     115 Map a function over all of the scalar values of a grouping, maintaining the
#     116 grouping structure
#    (...)
#     121     values updated by the input function.
#     122 """
#     123 if isinstance(grouping, (tuple, list)):
# --> 124     return [map_grouping(fn, g) for g in grouping]
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F921A790>
#         g = 1
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:129, in map_grouping(
#     fn=<function Dash.dispatch.<locals>.<lambda>>,
#     grouping=1
# )
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
# --> 129 return fn(grouping)
#         grouping = 1
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F921A790>
#
# File ~\anaconda3\lib\site-packages\dash\dash.py:1215, in Dash.dispatch.<locals>.<lambda>(ind=1)
#    1211             update_args_group(pattern_match_g, changed_props)
#    1212     update_args_group(s, changed_props)
#    1214 args_grouping = map_grouping(
# -> 1215     lambda ind: inputs_state[ind], inputs_state_indices
#         inputs_state = [{'id': 'my-input', 'property': 'value', 'value': 'sultan', 'str_id': 'my-input', 'triggered': True}]
#         ind = 1
#    1216 )
#    1218 g.args_grouping = args_grouping  # pylint: disable=assigning-non-slot
#    1219 g.using_args_grouping = (  # pylint: disable=assigning-non-slot
#    1220     not isinstance(inputs_state_indices, int)
#    1221     and (
#    (...)
#    1224     )
#    1225 )
#
# IndexError: list index out of range
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\flask\app.py:1950, in Flask.full_dispatch_request(self=<Flask '__main__'>)
#    1948     rv = self.preprocess_request()
#    1949     if rv is None:
# -> 1950         rv = self.dispatch_request()
#         rv = None
#         self = <Flask '__main__'>
#    1951 except Exception as e:
#    1952     rv = self.handle_user_exception(e)
#
# File ~\anaconda3\lib\site-packages\flask\app.py:1936, in Flask.dispatch_request(self=<Flask '__main__'>)
#    1934     return self.make_default_options_response()
#    1935 # otherwise dispatch to the handler for that endpoint
# -> 1936 return self.view_functions[rule.endpoint](**req.view_args)
#         req = <Request 'http://127.0.0.1:8050/_dash-update-component' [POST]>
#         rule = <Rule '/_dash-update-component' (POST, OPTIONS) -> /_dash-update-component>
#         self.view_functions[rule.endpoint] = <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>
#         self.view_functions = {'static': <bound method _PackageBoundObject.send_static_file of <Flask '__main__'>>, '_dash_assets.static': <bound method _PackageBoundObject.send_static_file of <flask.blueprints.Blueprint object at 0x00000200F82DC850>>, '/_dash-component-suites/<string:package_name>/<path:fingerprinted_path>': <bound method Dash.serve_component_suites of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-layout': <bound method Dash.serve_layout of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-dependencies': <bound method Dash.dependencies of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-update-component': <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_reload-hash': <bound method Dash.serve_reload_hash of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_favicon.ico': <function Dash._serve_default_favicon at 0x00000200F7FC8CA0>, '/': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/<path:path>': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, 'alive': <function JupyterDash.__init__.<locals>.alive at 0x00000200F6828E50>}
#         rule.endpoint = '/_dash-update-component'
#         req.view_args = {}
#         self = <Flask '__main__'>
#
# File ~\anaconda3\lib\site-packages\dash\dash.py:1214, in Dash.dispatch(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1211             update_args_group(pattern_match_g, changed_props)
#    1212     update_args_group(s, changed_props)
# -> 1214 args_grouping = map_grouping(
#         inputs_state_indices = [0, 1]
#         inputs_state = [{'id': 'my-input', 'property': 'value', 'value': 'sulta', 'str_id': 'my-input', 'triggered': True}]
#    1215     lambda ind: inputs_state[ind], inputs_state_indices
#    1216 )
#    1218 g.args_grouping = args_grouping  # pylint: disable=assigning-non-slot
#    1219 g.using_args_grouping = (  # pylint: disable=assigning-non-slot
#    1220     not isinstance(inputs_state_indices, int)
#    1221     and (
#    (...)
#    1224     )
#    1225 )
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:124, in map_grouping(
#     fn=<function Dash.dispatch.<locals>.<lambda>>,
#     grouping=[0, 1]
# )
#     114 """
#     115 Map a function over all of the scalar values of a grouping, maintaining the
#     116 grouping structure
#    (...)
#     121     values updated by the input function.
#     122 """
#     123 if isinstance(grouping, (tuple, list)):
# --> 124     return [map_grouping(fn, g) for g in grouping]
#         grouping = [0, 1]
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F93D3670>
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:124, in <listcomp>(.0=<list_iterator object>)
#     114 """
#     115 Map a function over all of the scalar values of a grouping, maintaining the
#     116 grouping structure
#    (...)
#     121     values updated by the input function.
#     122 """
#     123 if isinstance(grouping, (tuple, list)):
# --> 124     return [map_grouping(fn, g) for g in grouping]
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F93D3670>
#         g = 1
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:129, in map_grouping(
#     fn=<function Dash.dispatch.<locals>.<lambda>>,
#     grouping=1
# )
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
# --> 129 return fn(grouping)
#         grouping = 1
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F93D3670>
#
# File ~\anaconda3\lib\site-packages\dash\dash.py:1215, in Dash.dispatch.<locals>.<lambda>(ind=1)
#    1211             update_args_group(pattern_match_g, changed_props)
#    1212     update_args_group(s, changed_props)
#    1214 args_grouping = map_grouping(
# -> 1215     lambda ind: inputs_state[ind], inputs_state_indices
#         inputs_state = [{'id': 'my-input', 'property': 'value', 'value': 'sulta', 'str_id': 'my-input', 'triggered': True}]
#         ind = 1
#    1216 )
#    1218 g.args_grouping = args_grouping  # pylint: disable=assigning-non-slot
#    1219 g.using_args_grouping = (  # pylint: disable=assigning-non-slot
#    1220     not isinstance(inputs_state_indices, int)
#    1221     and (
#    (...)
#    1224     )
#    1225 )
#
# IndexError: list index out of range
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\flask\app.py:1950, in Flask.full_dispatch_request(self=<Flask '__main__'>)
#    1948     rv = self.preprocess_request()
#    1949     if rv is None:
# -> 1950         rv = self.dispatch_request()
#         rv = None
#         self = <Flask '__main__'>
#    1951 except Exception as e:
#    1952     rv = self.handle_user_exception(e)
#
# File ~\anaconda3\lib\site-packages\flask\app.py:1936, in Flask.dispatch_request(self=<Flask '__main__'>)
#    1934     return self.make_default_options_response()
#    1935 # otherwise dispatch to the handler for that endpoint
# -> 1936 return self.view_functions[rule.endpoint](**req.view_args)
#         req = <Request 'http://127.0.0.1:8050/_dash-update-component' [POST]>
#         rule = <Rule '/_dash-update-component' (POST, OPTIONS) -> /_dash-update-component>
#         self.view_functions[rule.endpoint] = <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>
#         self.view_functions = {'static': <bound method _PackageBoundObject.send_static_file of <Flask '__main__'>>, '_dash_assets.static': <bound method _PackageBoundObject.send_static_file of <flask.blueprints.Blueprint object at 0x00000200F82DC850>>, '/_dash-component-suites/<string:package_name>/<path:fingerprinted_path>': <bound method Dash.serve_component_suites of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-layout': <bound method Dash.serve_layout of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-dependencies': <bound method Dash.dependencies of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-update-component': <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_reload-hash': <bound method Dash.serve_reload_hash of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_favicon.ico': <function Dash._serve_default_favicon at 0x00000200F7FC8CA0>, '/': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/<path:path>': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, 'alive': <function JupyterDash.__init__.<locals>.alive at 0x00000200F6828E50>}
#         rule.endpoint = '/_dash-update-component'
#         req.view_args = {}
#         self = <Flask '__main__'>
#
# File ~\anaconda3\lib\site-packages\dash\dash.py:1214, in Dash.dispatch(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1211             update_args_group(pattern_match_g, changed_props)
#    1212     update_args_group(s, changed_props)
# -> 1214 args_grouping = map_grouping(
#         inputs_state_indices = [0, 1]
#         inputs_state = [{'id': 'my-input', 'property': 'value', 'value': 'sult', 'str_id': 'my-input', 'triggered': True}]
#    1215     lambda ind: inputs_state[ind], inputs_state_indices
#    1216 )
#    1218 g.args_grouping = args_grouping  # pylint: disable=assigning-non-slot
#    1219 g.using_args_grouping = (  # pylint: disable=assigning-non-slot
#    1220     not isinstance(inputs_state_indices, int)
#    1221     and (
#    (...)
#    1224     )
#    1225 )
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:124, in map_grouping(
#     fn=<function Dash.dispatch.<locals>.<lambda>>,
#     grouping=[0, 1]
# )
#     114 """
#     115 Map a function over all of the scalar values of a grouping, maintaining the
#     116 grouping structure
#    (...)
#     121     values updated by the input function.
#     122 """
#     123 if isinstance(grouping, (tuple, list)):
# --> 124     return [map_grouping(fn, g) for g in grouping]
#         grouping = [0, 1]
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F930AB80>
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:124, in <listcomp>(.0=<list_iterator object>)
#     114 """
#     115 Map a function over all of the scalar values of a grouping, maintaining the
#     116 grouping structure
#    (...)
#     121     values updated by the input function.
#     122 """
#     123 if isinstance(grouping, (tuple, list)):
# --> 124     return [map_grouping(fn, g) for g in grouping]
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F930AB80>
#         g = 1
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:129, in map_grouping(
#     fn=<function Dash.dispatch.<locals>.<lambda>>,
#     grouping=1
# )
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
# --> 129 return fn(grouping)
#         grouping = 1
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F930AB80>
#
# File ~\anaconda3\lib\site-packages\dash\dash.py:1215, in Dash.dispatch.<locals>.<lambda>(ind=1)
#    1211             update_args_group(pattern_match_g, changed_props)
#    1212     update_args_group(s, changed_props)
#    1214 args_grouping = map_grouping(
# -> 1215     lambda ind: inputs_state[ind], inputs_state_indices
#         inputs_state = [{'id': 'my-input', 'property': 'value', 'value': 'sult', 'str_id': 'my-input', 'triggered': True}]
#         ind = 1
#    1216 )
#    1218 g.args_grouping = args_grouping  # pylint: disable=assigning-non-slot
#    1219 g.using_args_grouping = (  # pylint: disable=assigning-non-slot
#    1220     not isinstance(inputs_state_indices, int)
#    1221     and (
#    (...)
#    1224     )
#    1225 )
#
# IndexError: list index out of range
#
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\flask\app.py:1950, in Flask.full_dispatch_request(self=<Flask '__main__'>)
#    1948     rv = self.preprocess_request()
#    1949     if rv is None:
# -> 1950         rv = self.dispatch_request()
#         rv = None
#         self = <Flask '__main__'>
#    1951 except Exception as e:
#    1952     rv = self.handle_user_exception(e)
#
# File ~\anaconda3\lib\site-packages\flask\app.py:1936, in Flask.dispatch_request(self=<Flask '__main__'>)
#    1934     return self.make_default_options_response()
#    1935 # otherwise dispatch to the handler for that endpoint
# -> 1936 return self.view_functions[rule.endpoint](**req.view_args)
#         req = <Request 'http://127.0.0.1:8050/_dash-update-component' [POST]>
#         rule = <Rule '/_dash-update-component' (POST, OPTIONS) -> /_dash-update-component>
#         self.view_functions[rule.endpoint] = <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>
# ...
#         rule.endpoint = '/_dash-update-component'
#         req.view_args = {}
#         self = <Flask '__main__'>
#
# File ~\anaconda3\lib\site-packages\dash\dash.py:1214, in Dash.dispatch(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1211             update_args_group(pattern_match_g, changed_props)
#    1212     update_args_group(s, changed_props)
# -> 1214 args_grouping = map_grouping(
#         inputs_state_indices = [0, 1]
#         inputs_state = [{'id': 'my-input', 'property': 'value', 'value': 'su', 'str_id': 'my-input', 'triggered': True}]
#    1215     lambda ind: inputs_state[ind], inputs_state_indices
#    1216 )
#    1218 g.args_grouping = args_grouping  # pylint: disable=assigning-non-slot
#    1219 g.using_args_grouping = (  # pylint: disable=assigning-non-slot
#    1220     not isinstance(inputs_state_indices, int)
#    1221     and (
#    (...)
#    1224     )
#    1225 )
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:124, in map_grouping(fn=<function Dash.dispatch.<locals>.<lambda>>, grouping=[0, 1])
#     114 """
#     115 Map a function over all of the scalar values of a grouping, maintaining the
#     116 grouping structure
#    (...)
#     121     values updated by the input function.
#     122 """
#     123 if isinstance(grouping, (tuple, list)):
# --> 124     return [map_grouping(fn, g) for g in grouping]
#         grouping = [0, 1]
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F94E20D0>
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:124, in <listcomp>(.0=<list_iterator object>)
#     114 """
#     115 Map a function over all of the scalar values of a grouping, maintaining the
#     116 grouping structure
#    (...)
#     121     values updated by the input function.
#     122 """
#     123 if isinstance(grouping, (tuple, list)):
# --> 124     return [map_grouping(fn, g) for g in grouping]
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F94E20D0>
#         g = 1
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:129, in map_grouping(fn=<function Dash.dispatch.<locals>.<lambda>>, grouping=1)
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
# --> 129 return fn(grouping)
#         grouping = 1
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F94E20D0>
#
# File ~\anaconda3\lib\site-packages\dash\dash.py:1215, in Dash.dispatch.<locals>.<lambda>(ind=1)
#    1211             update_args_group(pattern_match_g, changed_props)
#    1212     update_args_group(s, changed_props)
#    1214 args_grouping = map_grouping(
# -> 1215     lambda ind: inputs_state[ind], inputs_state_indices
#         inputs_state = [{'id': 'my-input', 'property': 'value', 'value': 'su', 'str_id': 'my-input', 'triggered': True}]
#         ind = 1
#    1216 )
#    1218 g.args_grouping = args_grouping  # pylint: disable=assigning-non-slot
#    1219 g.using_args_grouping = (  # pylint: disable=assigning-non-slot
#    1220     not isinstance(inputs_state_indices, int)
#    1221     and (
#    (...)
#    1224     )
#    1225 )
#
# IndexError: list index out of range
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\flask\app.py:1950, in Flask.full_dispatch_request(self=<Flask '__main__'>)
#    1948     rv = self.preprocess_request()
#    1949     if rv is None:
# -> 1950         rv = self.dispatch_request()
#         rv = None
#         self = <Flask '__main__'>
#    1951 except Exception as e:
#    1952     rv = self.handle_user_exception(e)
#
# File ~\anaconda3\lib\site-packages\flask\app.py:1936, in Flask.dispatch_request(self=<Flask '__main__'>)
#    1934     return self.make_default_options_response()
#    1935 # otherwise dispatch to the handler for that endpoint
# -> 1936 return self.view_functions[rule.endpoint](**req.view_args)
#         req = <Request 'http://127.0.0.1:8050/_dash-update-component' [POST]>
#         rule = <Rule '/_dash-update-component' (POST, OPTIONS) -> /_dash-update-component>
#         self.view_functions[rule.endpoint] = <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>
#         self.view_functions = {'static': <bound method _PackageBoundObject.send_static_file of <Flask '__main__'>>, '_dash_assets.static': <bound method _PackageBoundObject.send_static_file of <flask.blueprints.Blueprint object at 0x00000200F82DC850>>, '/_dash-component-suites/<string:package_name>/<path:fingerprinted_path>': <bound method Dash.serve_component_suites of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-layout': <bound method Dash.serve_layout of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-dependencies': <bound method Dash.dependencies of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-update-component': <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_reload-hash': <bound method Dash.serve_reload_hash of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_favicon.ico': <function Dash._serve_default_favicon at 0x00000200F7FC8CA0>, '/': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/<path:path>': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, 'alive': <function JupyterDash.__init__.<locals>.alive at 0x00000200F6828E50>}
#         rule.endpoint = '/_dash-update-component'
#         req.view_args = {}
#         self = <Flask '__main__'>
#
# File ~\anaconda3\lib\site-packages\dash\dash.py:1214, in Dash.dispatch(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1211             update_args_group(pattern_match_g, changed_props)
#    1212     update_args_group(s, changed_props)
# -> 1214 args_grouping = map_grouping(
#         inputs_state_indices = [0, 1]
#         inputs_state = [{'id': 'my-input', 'property': 'value', 'value': 's', 'str_id': 'my-input', 'triggered': True}]
#    1215     lambda ind: inputs_state[ind], inputs_state_indices
#    1216 )
#    1218 g.args_grouping = args_grouping  # pylint: disable=assigning-non-slot
#    1219 g.using_args_grouping = (  # pylint: disable=assigning-non-slot
#    1220     not isinstance(inputs_state_indices, int)
#    1221     and (
#    (...)
#    1224     )
#    1225 )
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:124, in map_grouping(
#     fn=<function Dash.dispatch.<locals>.<lambda>>,
#     grouping=[0, 1]
# )
#     114 """
#     115 Map a function over all of the scalar values of a grouping, maintaining the
#     116 grouping structure
#    (...)
#     121     values updated by the input function.
#     122 """
#     123 if isinstance(grouping, (tuple, list)):
# --> 124     return [map_grouping(fn, g) for g in grouping]
#         grouping = [0, 1]
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F94094C0>
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:124, in <listcomp>(.0=<list_iterator object>)
#     114 """
#     115 Map a function over all of the scalar values of a grouping, maintaining the
#     116 grouping structure
#    (...)
#     121     values updated by the input function.
#     122 """
#     123 if isinstance(grouping, (tuple, list)):
# --> 124     return [map_grouping(fn, g) for g in grouping]
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F94094C0>
#         g = 1
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:129, in map_grouping(
#     fn=<function Dash.dispatch.<locals>.<lambda>>,
#     grouping=1
# )
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
# --> 129 return fn(grouping)
#         grouping = 1
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F94094C0>
#
# File ~\anaconda3\lib\site-packages\dash\dash.py:1215, in Dash.dispatch.<locals>.<lambda>(ind=1)
#    1211             update_args_group(pattern_match_g, changed_props)
#    1212     update_args_group(s, changed_props)
#    1214 args_grouping = map_grouping(
# -> 1215     lambda ind: inputs_state[ind], inputs_state_indices
#         inputs_state = [{'id': 'my-input', 'property': 'value', 'value': 's', 'str_id': 'my-input', 'triggered': True}]
#         ind = 1
#    1216 )
#    1218 g.args_grouping = args_grouping  # pylint: disable=assigning-non-slot
#    1219 g.using_args_grouping = (  # pylint: disable=assigning-non-slot
#    1220     not isinstance(inputs_state_indices, int)
#    1221     and (
#    (...)
#    1224     )
#    1225 )
#
# IndexError: list index out of range
#
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\flask\app.py:1950, in Flask.full_dispatch_request(self=<Flask '__main__'>)
#    1948     rv = self.preprocess_request()
#    1949     if rv is None:
# -> 1950         rv = self.dispatch_request()
#         rv = None
#         self = <Flask '__main__'>
#    1951 except Exception as e:
#    1952     rv = self.handle_user_exception(e)
#
# File ~\anaconda3\lib\site-packages\flask\app.py:1936, in Flask.dispatch_request(self=<Flask '__main__'>)
#    1934     return self.make_default_options_response()
#    1935 # otherwise dispatch to the handler for that endpoint
# -> 1936 return self.view_functions[rule.endpoint](**req.view_args)
#         req = <Request 'http://127.0.0.1:8050/_dash-update-component' [POST]>
#         rule = <Rule '/_dash-update-component' (POST, OPTIONS) -> /_dash-update-component>
#         self.view_functions[rule.endpoint] = <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>
#         self.view_functions = {'static': <bound method _PackageBoundObject.send_static_file of <Flask '__main__'>>, '_dash_assets.static': <bound method _PackageBoundObject.send_static_file of <flask.blueprints.Blueprint object at 0x00000200F82DC850>>, '/_dash-component-suites/<string:package_name>/<path:fingerprinted_path>': <bound method Dash.serve_component_suites of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-layout': <bound method Dash.serve_layout of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-dependencies': <bound method Dash.dependencies of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_dash-update-component': <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_reload-hash': <bound method Dash.serve_reload_hash of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/_favicon.ico': <function Dash._serve_default_favicon at 0x00000200F7FC8CA0>, '/': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, '/<path:path>': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000200F82E3700>>, 'alive': <function JupyterDash.__init__.<locals>.alive at 0x00000200F6828E50>}
#         rule.endpoint = '/_dash-update-component'
#         req.view_args = {}
#         self = <Flask '__main__'>
#
# File ~\anaconda3\lib\site-packages\dash\dash.py:1214, in Dash.dispatch(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1211             update_args_group(pattern_match_g, changed_props)
#    1212     update_args_group(s, changed_props)
# -> 1214 args_grouping = map_grouping(
#         inputs_state_indices = [0, 1]
#         inputs_state = [{'id': 'my-input', 'property': 'value', 'value': '', 'str_id': 'my-input', 'triggered': True}]
#    1215     lambda ind: inputs_state[ind], inputs_state_indices
#    1216 )
#    1218 g.args_grouping = args_grouping  # pylint: disable=assigning-non-slot
#    1219 g.using_args_grouping = (  # pylint: disable=assigning-non-slot
#    1220     not isinstance(inputs_state_indices, int)
#    1221     and (
#    (...)
#    1224     )
#    1225 )
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:124, in map_grouping(
#     fn=<function Dash.dispatch.<locals>.<lambda>>,
#     grouping=[0, 1]
# )
#     114 """
#     115 Map a function over all of the scalar values of a grouping, maintaining the
#     116 grouping structure
#    (...)
#     121     values updated by the input function.
#     122 """
#     123 if isinstance(grouping, (tuple, list)):
# --> 124     return [map_grouping(fn, g) for g in grouping]
#         grouping = [0, 1]
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F9578F70>
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:124, in <listcomp>(.0=<list_iterator object>)
#     114 """
#     115 Map a function over all of the scalar values of a grouping, maintaining the
#     116 grouping structure
#    (...)
#     121     values updated by the input function.
#     122 """
#     123 if isinstance(grouping, (tuple, list)):
# --> 124     return [map_grouping(fn, g) for g in grouping]
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F9578F70>
#         g = 1
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
#
# File ~\anaconda3\lib\site-packages\dash\_grouping.py:129, in map_grouping(
#     fn=<function Dash.dispatch.<locals>.<lambda>>,
#     grouping=1
# )
#     126 if isinstance(grouping, dict):
#     127     return AttributeDict({k: map_grouping(fn, g) for k, g in grouping.items()})
# --> 129 return fn(grouping)
#         grouping = 1
#         fn = <function Dash.dispatch.<locals>.<lambda> at 0x00000200F9578F70>
#
# File ~\anaconda3\lib\site-packages\dash\dash.py:1215, in Dash.dispatch.<locals>.<lambda>(ind=1)
#    1211             update_args_group(pattern_match_g, changed_props)
#    1212     update_args_group(s, changed_props)
#    1214 args_grouping = map_grouping(
# -> 1215     lambda ind: inputs_state[ind], inputs_state_indices
#         inputs_state = [{'id': 'my-input', 'property': 'value', 'value': '', 'str_id': 'my-input', 'triggered': True}]
#         ind = 1
#    1216 )
#    1218 g.args_grouping = args_grouping  # pylint: disable=assigning-non-slot
#    1219 g.using_args_grouping = (  # pylint: disable=assigning-non-slot
#    1220     not isinstance(inputs_state_indices, int)
#    1221     and (
#    (...)
#    1224     )
#    1225 )
#
# IndexError: list index out of range

# %% [markdown]
# # Q4.1: Make JubyterDash with Rangeslider from 1-15 with 6 option

# %%
app = JupyterDash(__name__) 
# app = Dash(__name__)


app.layout = html.Div([
    html.H4('Interactive plot with custom data source'),
    
    html.P("q4.1"),
    dcc.RangeSlider(id="slider", min=1, max=15,  step=3),
])


@app.callback(
    Input("slider", "value"))
    
def Display(sl):
    return sl

# app.run()  
app.run_server(use_reloader=False, mode='inline') # Turn off reloader if inside Jupyter
# Out:
# Dash is running on http://127.0.0.1:8050/
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Q4.2: add to the previous dash: Label, set default value on rangeslider as 7-10

# %%
app = JupyterDash(__name__) 
# app = Dash(__name__)


app.layout = html.Div([
    
    
    html.P("Q4.2"),
    dcc.RangeSlider(id="slider", min=1, max=15, value=[7,10], step=3),
])


@app.callback(
    Input("slider", "value"))
    
def Display(sl):
    return sl

# app.run()  
app.run_server(use_reloader=False, mode='inline') # Turn off reloader if inside Jupyter
# Out:
# Dash is running on http://127.0.0.1:8050/
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Q5: Make 3 different Dcc types (Dropdown - Checkbox...) in one dash

# %%
app = JupyterDash(__name__)


app.layout = html.Div([
    html.H4('Q5'),
    html.P("Dropdown:"),
    dcc.Dropdown(
        id="dropdown",
        options=['test1', 'test2', 'test3'],
    ),
    html.P("CheckList"),
        dcc.Checklist(
        ['t1', 't2', 't3'],
        inline=True
    ),
    html.P("RangeSlider : "),
    dcc.RangeSlider(id="slider", min=1, max=15, value=[7,10], step=3)
])




app.run_server(mode='inline')
# Out:
# Dash is running on http://127.0.0.1:8050/
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Q6: Make Plotly chart, then add it to a plotly_dash

# %%
import plotly.express as px
import numpy as np

# %%
from dash import Dash, dcc, html, Input, Output
import plotly.graph_objects as go
import numpy as np
from jupyter_dash import JupyterDash


app = JupyterDash(__name__) 
# app = Dash(__name__)


app.layout = html.Div([
    html.H4('Q6'),
    dcc.Graph(id="graph"),
    html.P("Number of bars:"),
    dcc.Slider(id="slider", min=2, max=10, value=4, step=1),
])


@app.callback(
    Output("graph", "figure"), 
    Input("slider", "value"))
    
def update_bar_chart(size):
    data = np.random.uniform(3, 2, size=size)
    fig = go.Figure(
        data=[go.Bar(y=data)]
    )
    return fig

# app.run()  
app.run_server(use_reloader=False, mode='inline')
# Out:
# Dash is running on http://127.0.0.1:8050/
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Q7: From our data make plotly-dash with suitble chart, and Dropdown.
#
# - Dropdown should contain at least 3 options, each one represents different column.
# - Add label to dropdown.
# - The chart data should change depending on the selected dropdown option.

# %%
from dash import Dash, dcc, html, Input, Output
import plotly.express as px
from dash import Dash, dcc, html, Input, Output
import plotly.express as px


import pandas as pd

df=pd.read_csv("titanic passenger list.csv")


app = Dash(__name__)

app.layout = html.Div([
    html.H4('Show Survived based on 2 x-axis '),
    dcc.Dropdown(
        id="dropdown",
        options=['embarked','sex'],
        #value=['embarked', 'sex'],
        multi=True
    ),
    dcc.Graph(id="graph"),
])


@app.callback(
    Output("graph", "figure"), 
    Input("dropdown", "value"))
def Display(x_axis):
    return px.box(data_frame=df,x=x_axis,y=df["survived"])


app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [31/May/2023 19:39:12] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2023 19:39:12] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2023 19:39:12] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2023 19:39:12] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2023 19:39:12] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2023 19:39:12] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2023 19:39:13] "POST /_dash-update-component HTTP/1.1" 200 -

# %%
# from dash import Dash, dcc, html, Input, Output
# import plotly.express as px
# from dash import Dash, dcc, html, Input, Output
# import plotly.express as px
# import pandas as pd
# from dash import Dash, dcc, html, Input, Output
# import plotly.graph_objects as go
# from jupyter_dash import JupyterDash
# from dash import Dash, html

# %% [markdown]
# # Q8: add 2 more charts to the prevoius Ploty-Dash

# %%
from dash import Dash, dcc, html, Input, Output
import plotly.express as px
from dash import Dash, dcc, html, Input, Output
import plotly.express as px


import pandas as pd

df=pd.read_csv("titanic passenger list.csv")


app = Dash(__name__)

app.layout = html.Div([
    html.H4('Show Survived based on 2 x-axis '),
    dcc.Dropdown(
        id="dropdown",
        options=['embarked','sex'],
        #value=['embarked', 'sex'],
        multi=True
    ),
    dcc.Graph(id="graph"),
    dcc.Graph(id="New_plot",figure=px.bar(data_frame=df,y=df["survived"],x=df["age"])),
    dcc.Graph(id="Pie_plot",figure=px.pie(df,df["pclass"]))
])


@app.callback(
    Output("graph", "figure"), 
    Input("dropdown", "value"))
def Display(x_axis):
    return px.box(data_frame=df,x=x_axis,y=df["survived"])


app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [31/May/2023 19:40:04] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2023 19:40:04] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2023 19:40:04] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2023 19:40:04] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2023 19:40:04] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2023 19:40:04] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2023 19:40:04] "POST /_dash-update-component HTTP/1.1" 200 -

# %% [markdown]
# # Q9: Search for "Plotly Gallery" and fetch for a graph and use it with our data.
#
# - Note: You need to put the resourse addres of fetched your grapth.

# %%
# resource https://plotly.com/python/histograms/

df=pd.read_csv("titanic passenger list.csv")


app = Dash(__name__)

app.layout = html.Div([
    html.H4('Show Survived based on 2 x-axis '),
    dcc.Dropdown(
        id="dropdown",
        options=['embarked','sex'],
        #value=['embarked', 'sex'],
        multi=True
    ),
    dcc.Graph(id="graph"),
])


@app.callback(
    Output("graph", "figure"), 
    Input("dropdown", "value"))
def update_bar_chart(x_axis):
    return px.histogram(df, x=x_axis)


app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [31/May/2023 19:40:34] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2023 19:40:34] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2023 19:40:34] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2023 19:40:34] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2023 19:40:34] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2023 19:40:34] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# [2023-05-31 19:40:34,676] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\ttsul\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\ttsul\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\ttsul\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\ttsul\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\ttsul\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\ttsul\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\ttsul\anaconda3\lib\site-packages\dash\dash.py", line 1249, in dispatch
#     ctx.run(
#   File "C:\Users\ttsul\anaconda3\lib\site-packages\dash\_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\ttsul\AppData\Local\Temp\ipykernel_11288\1968384328.py", line 24, in update_bar_chart
#     return px.histogram(df, x=x_axis)
#   File "C:\Users\ttsul\anaconda3\lib\site-packages\plotly\express\_chart_types.py", line 472, in histogram
#     return make_figure(
#   File "C:\Users\ttsul\anaconda3\lib\site-packages\plotly\express\_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "C:\Users\ttsul\anaconda3\lib\site-packages\plotly\express\_core.py", line 1452, in build_dataframe
#     raise ValueError(
# ValueError: Plotly Express cannot process wide-form data with columns of different type.
# 127.0.0.1 - - [31/May/2023 19:40:34] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [31/May/2023 19:40:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2023 19:40:39] "POST /_dash-update-component HTTP/1.1" 200 -

# %% [markdown]
# # Challenge 1.1: Create Plotly dash with two charts depends on different columns of the data
# - First Chart : Pie
# - Secound Chart: is by your Choice ( Not Pie )

# %% [markdown]
# # Challenge 1.2: Make Hovering over a slice of the pie changes the data for the second chart depending on what the slice is.
